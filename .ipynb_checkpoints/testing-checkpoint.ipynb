# %%
# %load_ext autoreload
# %autoreload 2
from search import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
G = graph.Graph('data/tiny_network.adjlist')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 G = graph.Graph('data/tiny_network.adjlist')
#
# NameError: name 'graph' is not defined

# %%
print(G.graph.edges())
# Out:
# [('31806696', 'Luke Gilbert'), ('Luke Gilbert', '33483487'), ('Luke Gilbert', '31806696'), ('Luke Gilbert', '31626775'), ('Luke Gilbert', '31540829'), ('31486345', 'Michael Keiser'), ('31486345', 'Marina Sirota'), ('Michael Keiser', '33232663'), ('Marina Sirota', '31486345'), ('29700475', 'Michael Keiser'), ('29700475', 'Nevan Krogan'), ('Nevan Krogan', '34272374'), ('Nevan Krogan', '32353859'), ('Nevan Krogan', '30944313'), ('33765435', 'Marina Sirota'), ('32025019', 'Atul Butte'), ('32025019', 'Hani Goodarzi'), ('Atul Butte', '33765435'), ('Atul Butte', '33242416'), ('Atul Butte', '31395880'), ('Atul Butte', '30944313'), ('Hani Goodarzi', '33232663'), ('34272374', 'Martin Kampmann'), ('32353859', 'Atul Butte'), ('32353859', 'Martin Kampmann'), ('32353859', 'Nevan Krogan'), ('32353859', 'Marina Sirota'), ('30944313', 'Hani Goodarzi'), ('30944313', 'Nevan Krogan'), ('30944313', 'Marina Sirota'), ('Neil Risch', '29700475'), ('33483487', 'Luke Gilbert'), ('33483487', 'Martin Kampmann')
# ...

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
nx.draw(G.graph)
plt.show()

# %%
start = 'Luke'
start in G.graph.nodes()
# Out:
# False

# %%
G.bfs(start = 'Luke Gilbert1', end = 'Martin Kampmann1')
# Out:
# Looking for: Martin Kampmann1
# shrey
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Users/smenon/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/cw/0j3799wn54v00326qp8dp33m0000gq/T/ipykernel_90003/4237378154.py", line 1, in <cell line: 1>
#     G.bfs(start = 'Luke Gilbert1', end = 'Martin Kampmann1')
#   File "/Users/smenon/BMI203/HW2-BFS-shreya/search/graph.py", line 38, in bfs
#     pass ValueError(f"Start node not found in graph")
# ValueError: Start node not found in graph
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/smenon/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py", line 1982, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
# ...

# %%
 G = graph.Graph('test/empty.adjlist')

# %%
G.graph.nodes()
# Out:
# NodeView(())

# %%
len(G.graph.edges()) == 0
# Out:
# True

# %%
G.graph.edges()
# Out:
# OutEdgeView([])
